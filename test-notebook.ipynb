# %% [markdown]
# # Notebook test
# This is being used to test some of the functionalities of Jupyter notebooks for Wordpress.

# %%
import numpy as np
from matplotlib import pyplot as plt

x, y = np.mgrid[0:100, 0:100]
z = x**2 + (y-50)**2

plt.contourf(x, y, z)
plt.show()
